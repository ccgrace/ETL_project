# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "Resources/HPI_master.csv"
hpi_master_df = pd.read_csv(csv_file)
hpi_master_df.head()
# Out:
#       hpi_type     hpi_flavor frequency                   level  \
# 0  traditional  purchase-only   monthly  USA or Census Division
# 1  traditional  purchase-only   monthly  USA or Census Division
# 2  traditional  purchase-only   monthly  USA or Census Division
# 3  traditional  purchase-only   monthly  USA or Census Division
# 4  traditional  purchase-only   monthly  USA or Census Division
#
#                     place_name place_id    yr  period  index_nsa  index_sa
# 0  East North Central Division   DV_ENC  1991       1     100.00    100.00
# 1  East North Central Division   DV_ENC  1991       2     100.98    101.06
# 2  East North Central Division   DV_ENC  1991       3     101.33    100.95
# 3  East North Central Division   DV_ENC  1991       4     101.72    101.02
# 4  East North Central Division   DV_ENC  1991       5     102.35    101.40

# %%
md_hpi = hpi_master_df.loc[hpi_master_df['place_id'] == 'MD']
md_hpi_rename = md_hpi.rename(columns = {'place_name':'State',
                        'hpi_type':'Data Type',
                        'hpi_flavor':'Index Type',
                        'frequency':'Collection Frequency',
                        'level':'Level',
                        'place_name':'State',
                        'place_id':'State (abrv.)',
                        'yr': 'Year',
                        'period': 'Collection Period',
                        'index_nsa': 'Non-Seasonally Adjusted Index',
                        'index_sa':'Seasonally Adjusted Index'})
md_hpi_rename.head()
# Out:
#          Data Type        Index Type Collection Frequency  Level     State  \
# 68011  traditional  all-transactions            quarterly  State  Maryland
# 68012  traditional  all-transactions            quarterly  State  Maryland
# 68013  traditional  all-transactions            quarterly  State  Maryland
# 68014  traditional  all-transactions            quarterly  State  Maryland
# 68015  traditional  all-transactions            quarterly  State  Maryland
#
#       State (abrv.)  Year  Collection Period  Non-Seasonally Adjusted Index  \
# 68011            MD  1975                  1                          61.78
# 68012            MD  1975                  2                          62.32
# 68013            MD  1975                  3                          64.99
# 68014            MD  1975                  4                          66.61
# 68015            MD  1976                  1                          66.92
#
#        Seasonally Adjusted Index
# ...

# %%
new_hpi = md_hpi_rename.reset_index(drop=True)
new_hpi.head()
# Out:
#      Data Type        Index Type Collection Frequency  Level     State  \
# 0  traditional  all-transactions            quarterly  State  Maryland
# 1  traditional  all-transactions            quarterly  State  Maryland
# 2  traditional  all-transactions            quarterly  State  Maryland
# 3  traditional  all-transactions            quarterly  State  Maryland
# 4  traditional  all-transactions            quarterly  State  Maryland
#
#   State (abrv.)  Year  Collection Period  Non-Seasonally Adjusted Index  \
# 0            MD  1975                  1                          61.78
# 1            MD  1975                  2                          62.32
# 2            MD  1975                  3                          64.99
# 3            MD  1975                  4                          66.61
# 4            MD  1976                  1                          66.92
#
#    Seasonally Adjusted Index
# 0                        NaN
# 1                        NaN
# ...
