# %%
#pip install psycopg2

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "Resources/grant_data.csv"
grant_data_df = pd.read_csv(csv_file)
grant_data_df.head()
# Out:
#    Fiscal Year                                  Awardee  \
# 0         2019   County Commissioners of Carroll County
# 1         2019   County Commissioners of Garrett County
# 2         2019                        Town of Betterton
# 3         2019  County Commissioners of Allegany County
# 4         2019                Wicomico County, Maryland
#
#               Project Name     Award         City    County
# 0  CHANGE Roof Replacement   90000.0  Westminster   Carroll
# 1         Parkwood Village  750000.0      Oakland   Garrett
# 2           Wheeler Avenue  800000.0    Betterton      Kent
# 3      Locust Grove Sewage  800000.0   Cumberland  Allegany
# 4   Downpayment Assistance  300000.0    Salisbury  Wicomico

# %%
modified_df = grant_data_df[['Fiscal Year', 'Awardee', 'City', 'County']]
modified_df
# Out:
#      Fiscal Year                                  Awardee         City  \
# 0           2019   County Commissioners of Carroll County  Westminster
# 1           2019   County Commissioners of Garrett County      Oakland
# 2           2019                        Town of Betterton    Betterton
# 3           2019  County Commissioners of Allegany County   Cumberland
# 4           2019                Wicomico County, Maryland    Salisbury
# ..           ...                                      ...          ...
# 265         2011                        City of Brunswick    Brunswick
# 266         2011                           Charles County          NaN
# 267         2011                           Carroll County  Westminster
# 268         2011                          Caroline County       Denton
# 269         2011                       Town of Greensboro   Greensboro
#
#         County
# 0      Carroll
# 1      Garrett
# 2         Kent
# 3     Allegany
# 4     Wicomico
# ..         ...
# 265  Frederick
# 266    Charles
# 267    Carroll
# 268   Caroline
# 269   Caroline
#
# [270 rows x 4 columns]
